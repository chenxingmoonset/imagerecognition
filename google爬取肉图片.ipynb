# %%
# -*- coding: utf-8 -*-
"""
 Created on 2021/4/19 11:47
 Filename   : spider_image_baidu.py
 Author     : Taosy
 Zhihu      : https://www.zhihu.com/people/1105936347
 Github     : https://github.com/AFei19911012
 Description: Spider - get images from baidu
"""

import requests
import os
import re


def get_images_from_baidu(keyword, page_num, save_dir):
    # UA 伪装：当前爬取信息伪装成浏览器
    # 将 User-Agent 封装到一个字典中
    # 【（网页右键 → 审查元素）或者 F12】 → 【Network】 → 【Ctrl+R】 → 左边选一项，右边在 【Response Hearders】 里查找
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}
    # 请求的 url
    url = 'https://image.baidu.com/search/acjson?'
    n = 0
    for pn in range(0, 30 * page_num, 30):
        # 请求参数
        param = {'tn': 'resultjson_com',
                 # 'logid': '7603311155072595725',
                 'ipn': 'rj',
                 'ct': 201326592,
                 'is': '',
                 'fp': 'result',
                 'queryWord': keyword,
                 'cl': 2,
                 'lm': -1,
                 'ie': 'utf-8',
                 'oe': 'utf-8',
                 'adpicid': '',
                 'st': -1,
                 'z': '',
                 'ic': '',
                 'hd': '',
                 'latest': '',
                 'copyright': '',
                 'word': keyword,
                 's': '',
                 'se': '',
                 'tab': '',
                 'width': '',
                 'height': '',
                 'face': 0,
                 'istype': 2,
                 'qc': '',
                 'nc': '1',
                 'fr': '',
                 'expermode': '',
                 'force': '',
                 'cg': '',    # 这个参数没公开，但是不可少
                 'pn': pn,    # 显示：30-60-90
                 'rn': '30',  # 每页显示 30 条
                 'gsm': '1e',
                 '1618827096642': ''
                 }
        request = requests.get(url=url, headers=header, params=param)
        if request.status_code == 200:
            print('Request success.')
        request.encoding = 'utf-8'
        # 正则方式提取图片链接
        html = request.text
        image_url_list = re.findall('"thumbURL":"(.*?)",', html, re.S)
        print(image_url_list)
        # # 换一种方式
        # request_dict = request.json()
        # info_list = request_dict['data']
        # # 看它的值最后多了一个，删除掉
        # info_list.pop()
        # image_url_list = []
        # for info in info_list:
        #     image_url_list.append(info['thumbURL'])

        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        for image_url in image_url_list:
            image_data = requests.get(url=image_url, headers=header).content
            with open(os.path.join(save_dir, f'{n:06d}.jpg'), 'wb') as fp:
                fp.write(image_data)
            n = n + 1


if __name__ == '__main__':
    keyword = '生五花肉'
    save_dir = keyword
    page_num = 2
    get_images_from_baidu(keyword, page_num, save_dir)
    print('Get images finished.')
# Out:
# Request success.
# ['https://img1.baidu.com/it/u=262098433,2747502634&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img1.baidu.com/it/u=848073118,2345421170&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=414664134,3402511984&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=4003237515,1667467197&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=4244072333,1981004787&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=1226581526,1733292923&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=1695272269,416628889&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=4162736869,4209280144&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=1419079578,498705663&fm=253&fmt=auto&app=138&f=JPEG?w=700&h=497', 'https://img0.baidu.com/it/u=1754203521,616373985&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=621', 'https://img2.baidu.com/it/u=1545667316,2359368061&fm=253&fmt=auto&app=138&f=JPEG?w=750&h=500', 'https://img2.baidu.com/it/u=896281517,4081295778&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=1126971671,17334735&fm=253&fmt=auto&app=138&f=JPEG?w=350&h=350', 'https://img1.baidu.com/it/u=3145077727,2220800101&fm=253&fmt=auto&app=138&f=PNG?w=350&h=350', 'https://img2.baidu.com/it/u=1052028446,118175711&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=1466910133,1994375499&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img1.baidu.com/it/u=799451124,3789076777&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=685', 'https://img1.baidu.com/it/u=2587457100,3758209260&fm=253&fmt=auto&app=138&f=JPEG?w=350&h=350', 'https://img1.baidu.com/it/u=1263103660,2073841702&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=4189306441,3770837765&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=3396534979,1000229180&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=1909612517,1744987057&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img1.baidu.com/it/u=4060512294,1392001458&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=3464221734,1753351878&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=616489411,950526003&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=1059188714,3378413246&fm=253&fmt=auto&app=138&f=JPEG?w=667&h=500', 'https://img2.baidu.com/it/u=1485042675,1050870569&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=333', 'https://img0.baidu.com/it/u=3747935362,1793362481&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=3572013334,1373920635&fm=253&fmt=auto&app=138&f=JPEG?w=400&h=400', 'http://t14.baidu.com/it/u=1418984745,3178093482&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t14.baidu.com/it/u=1418984745,3178093482&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t13.baidu.com/it/u=2984844264,4067578710&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t13.baidu.com/it/u=887495187,3922218450&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t14.baidu.com/it/u=2296776869,3102631943&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t15.baidu.com/it/u=3292034092,2678006527&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t15.baidu.com/it/u=971306606,3653407546&fm=224&app=112&f=JPEG?w=350&h=350']
# Request success.
# ['https://img1.baidu.com/it/u=2414414629,2276701641&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=2689153550,2654553757&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=2689153550,2654553757&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=1173635119,458450234&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=1663155692,4218574374&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=3738515126,1827880307&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=3196793980,108250818&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img1.baidu.com/it/u=1154976942,929724067&fm=253&fmt=auto&app=138&f=JPEG?w=350&h=350', 'https://img2.baidu.com/it/u=340306552,553743616&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=667', 'http://t13.baidu.com/it/u=1255542127,792535908&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=1255542127,792535908&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=4270464652,2721807670&fm=224&app=112&f=JPEG?w=350&h=350', 'http://t13.baidu.com/it/u=540760314,798078333&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=210077018,3919288017&fm=224&app=112&f=JPEG?w=350&h=350', 'https://img2.baidu.com/it/u=3379557821,342313319&fm=253&fmt=auto&app=138&f=JPEG?w=300&h=300', 'https://img2.baidu.com/it/u=3583325024,906582372&fm=253&fmt=auto&app=138&f=PNG?w=500&h=358', 'https://img2.baidu.com/it/u=3477458683,4086455652&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=2096330446,3557508195&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=4171615968,3254692636&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t15.baidu.com/it/u=4171615968,3254692636&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=644495159,1130479805&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=3740295875,501415495&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=3913253705,3804571913&fm=253&fmt=auto&app=138&f=PNG?w=250&h=250', 'https://img1.baidu.com/it/u=1235458632,3462014535&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=177569247,1842855635&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img1.baidu.com/it/u=1669184601,3322525211&fm=253&fmt=auto&app=138&f=JPEG?w=350&h=350', 'http://t14.baidu.com/it/u=1317185920,1767469733&fm=224&app=112&f=PNG?w=500&h=500&s=9BB474830FA65E8642D36DF10300D062', 'http://t14.baidu.com/it/u=1317185920,1767469733&fm=224&app=112&f=PNG?w=500&h=500&s=9BB474830FA65E8642D36DF10300D062', 'http://t14.baidu.com/it/u=1947814293,3248248202&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=776511954,1282791478&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=669511593,613675192&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=449280316,2350810170&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=425123393,95338712&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=3355522693,2936565685&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=1928711560,2555742841&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=144440839,1932168333&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=2260640664,256874637&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=2369672066,4157752115&fm=224&app=112&f=JPEG?w=500&h=500', 'https://img0.baidu.com/it/u=2281676540,663535039&fm=253&fmt=auto&app=138&f=JPEG?w=500&h=500', 'https://img2.baidu.com/it/u=344063354,3093038607&fm=253&fmt=auto&app=138&f=JPEG?w=350&h=350', 'https://img0.baidu.com/it/u=1295290942,2342765189&fm=253&fmt=auto&app=138&f=JPEG?w=300&h=300', 'http://t13.baidu.com/it/u=2911183050,3044449340&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=2911183050,3044449340&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t14.baidu.com/it/u=3096047475,2344777727&fm=224&app=112&f=JPEG?w=500&h=500', 'http://t13.baidu.com/it/u=3306024548,28687 ...
# Get images finished.
